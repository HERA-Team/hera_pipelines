# %% [markdown]
# # Bad Antennas for H1C IDR3.1
#
# Comissioning has given us a list of bad antenna-days. I want to harmonize these in a way that excludes antennas that have a good chance of being bad because they were marked as bad on neighboring days.
#
# For IDR2.1, any antenna that was marked as bad for more than one day was flagged for all days. That worked OK with 18 days, but is more problematic for 107 days. Instead, I've done the following:
#
# * I've broken the days into 4 epochs, separated by significant gaps the days. There are two days (2458172, and 2458173) that are between epochs, so I assign them to both.
# * If more than 10% of the days in an epoch are flagged for a given antenna, the antenna is flagged for the entire epoch.
# * If more than 60% of the days are flagged after the per-epoch cut (i.e. if 3/4 of the epochs are flagged), the antenna is flagged for all epochs (i.e. the entire season).
# * I also removed antennas 155, 156, 180, 181, 182, 183, 334, 338 because they aren't on the main redundantly calibratable grid. And I've removed 54 because it has a consistently high chi^2 per antenna in redcal.
#
# This expands the total number of flagged antenna-days from about 11% to about 20% of the total available (not including the off-grid antennas). Ideally, this conservative cut will help safeguard us for bad antennas in our calibration while not sacrificing too much sensitivity.

# %% [markdown]
# ## Update December 2019:
#
# I've run all of IDR3 through redcal and counted the number of times an antennas was considered a 4$\sigma$ outlier in in terms of its $\chi^2$ per antenna.
#
# The choices are justified here: https://github.com/HERA-Team/hera_sandbox/blob/master/jsd/IDR3_badants/IDR3_Bad_Ants.ipynb
#
# Harmonizing these flags, where appropriate, leads to additional flagging.

# %%
from __future__ import print_function, division, absolute_import

import csv
from collections import OrderedDict as odict
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy

# %%
off_grid = [155, 156, 180, 181, 182, 183, 334, 338]
# Not redundantly calibratable as stands

not_red = [0, 11, 24, 50, 53, 54, 67, 69, 98, 122, 136] 
# In my experiments with redcal, these antenna are often 4 sigma outliers in chi^2 per antenna 
# this is largely based on evidence with IDR2.2 and should be revisited for IDR3
# see https://files.slack.com/files-pri/T0KMWB8P3-FK7LHD8LD/image.png
# and https://files.slack.com/files-pri/T0KMWB8P3-FKERMDFLY/image.png
# and https://files.slack.com/files-pri/T0KMWB8P3-FK4FKKH6E/image.png

group1 = [2458041, 2458042, 2458043, 2458044, 2458045, 2458046, 2458047, 2458048, 2458049, 2458050, 2458051, 2458052, 2458054, 2458055, 2458056, 2458058, 2458059, 2458061, 2458062, 2458063, 2458064, 2458065, 2458066, 2458067, 2458068, 2458069, 2458070, 2458071, 2458072]
group2 = [2458081, 2458083, 2458084, 2458085, 2458086, 2458087, 2458088, 2458089, 2458090, 2458091, 2458092, 2458094, 2458095, 2458096, 2458097, 2458098, 2458099, 2458101, 2458102, 2458103, 2458104, 2458105, 2458106, 2458107, 2458108, 2458109, 2458110, 2458111, 2458112, 2458113, 2458114, 2458115, 2458116]
group3 = [2458134, 2458135, 2458136, 2458139, 2458140, 2458141, 2458142, 2458143, 2458144, 2458145, 2458146, 2458147, 2458148, 2458149, 2458150, 2458151, 2458153, 2458154, 2458155, 2458157, 2458158, 2458159, 2458161, 2458172, 2458173]
group4 = [2458172, 2458173, 2458185, 2458187, 2458188, 2458189, 2458190, 2458192, 2458195, 2458196, 2458197, 2458198, 2458199, 2458200, 2458201, 2458202, 2458203, 2458204, 2458205, 2458206, 2458207, 2458208]

# %%
JD_flags = {2458041: [[0.50, 0.70]], # from Josh's inspecting notebooks on 2/9/21
            2458049: [[0.10, 0.41]], # from Josh's inspecting notebooks on 2/9/21
            2458052: [[0.50, 0.90]], # from Josh's inspecting notebooks on 2/9/21
            2458054: [[0.10, 0.90]], # X-engine issues. Excluded whole day. From Josh's inspecting notebooks on 2/9/21
            2458055: [[0.10, 0.90]], # X-engine issues. Excluded whole day. From Josh's inspecting notebooks on 2/9/21
            2458056: [[0.10, 0.90]], # X-engine issues. Excluded whole day. From Josh's inspecting notebooks on 2/9/21
            2458058: [[0.10, 0.48]], # from Vignesh's by-hand analysis H1C IDR3.1, expanded by Josh on 2/9/21
            2458059: [[0.10, 0.48]], # from Vignesh's by-hand analysis H1C IDR3.1, expanded by Josh on 2/9/21
            2458061: [[0.10, 0.90]], # Broadband RFI issues. Excluded whole day. From Josh's inspecting notebooks on 2/9/21
            2458065: [[0.10, 0.90]], # Broadband RFI issues. Excluded whole day. From Josh's inspecting notebooks on 2/9/21
            2458066: [[0.10, 0.90]], # Broadband RFI issues. Excluded whole day. From Josh's inspecting notebooks on 2/9/21
            2458085: [[0.56, 0.90]], # Broadband RFI in last hour or so. From Josh's inspecting notebooks on 2/25/21
            2458088: [[0.52, 0.90]], # Narrowband RFI in last few hours. From Josh's inspecting notebooks on 2/25/21
            2458089: [[0.10, 0.90]], # Narrowband RFI in last few hours. From Josh's inspecting notebooks on 2/25/21. Flagged completely due to smooth_cal issues discovered 3/11/21 by Josh
            2458090: [[0.50, 0.90]], # Narrowband RFI in last few hours. From Josh's inspecting notebooks on 2/26/21
            2458095: [[0.10, 0.30],
                      [0.49, 0.58]], # Broadband RFI in at start of night and late in the night. From Josh's inspecting notebooks on 2/26/21
            2458096: [[0.10, 0.52]], # from Vignesh's by-hand analysis H1C IDR3.1, expanded by Josh's notebook inspection on 2/26/21
            2458104: [[0.10, 0.47]], # from Vignesh's by-hand analysis H1C IDR3.1, expanded by Josh's notebook inspection on 2/26/21
            2458105: [[0.10, 0.43]], # Broadband RFI for first half of the night. From Josh's inspecting notebooks on 2/26/21
            2458109: [[0.20, 0.46]], # from Vignesh's by-hand analysis H1C IDR3.1
            2458110: [[0.47, 0.90]], # Narrowband RFI in last few hours. From Josh's inspecting notebooks on 2/26/21
            2458114: [[0.10, 0.32]], # flagged due to a broken X-engine 
            2458135: [[0.10, 0.43]], # flagged due to excess broadband RFI. From Josh's inspecting notebooks on 3/9/21
            2458136: [[0.20, 0.43]], # from Vignesh's by-hand analysis H1C IDR3.1, expanded from Josh's inspecting notebooks on 3/9/21
            2458139: [[0.10, 0.34]], # flagged due to excess broadband RFI. From Josh's inspecting notebooks on 3/9/21
            2458140: [[0.10, 0.90]], # added by Josh on 12/29/20, expanded to full day flag from Josh's inspecting notebooks on 3/9/21
            2458141: [[0.10, 0.52]], # from Vignesh's by-hand analysis H1C IDR3.1. Expanded from Josh's inspecting notebooks on 3/9/21
            2458144: [[0.10, 0.31]], # flagged due to excess broadband RFI. From Josh's inspecting notebooks on 3/9/21
            2458145: [[0.10, 0.38]], # flagged due to excess broadband RFI. From Josh's inspecting notebooks on 3/9/21
            2458148: [[0.10, 0.37]], # from Vignesh's by-hand analysis H1C IDR3.1. Expanded from Josh's inspecting notebooks on 3/9/21
            2458157: [[0.46, 0.90]], # Omnical issues, possibly non-convergence. From Josh's inspecting notebooks on 3/9/21
            2458159: [[0.10, 0.90]], # from Vignesh's by-hand analysis H1C IDR3.1, expanded to full day flag from Josh's inspecting notebooks on 3/9/21
            2458161: [[0.10, 0.90]], # from Vignesh's by-hand analysis H1C IDR3.1. Excluded by Josh on inpsectiing notebooks 2/18/21
            2458172: [[0.10, 0.90]], # from Vignesh's by-hand analysis H1C IDR3.1. Excluded by Josh on inspecting notebooks 2/18/21
            2458173: [[0.10, 0.90]], # from Vignesh's by-hand analysis H1C IDR3.1. Excluded by Josh on inspecting notebooks 2/18/21
            2458185: [[0.10, 0.52]], # from Vignesh's by-hand analysis H1C IDR3.1. Expanded by Josh on inspecting notebooks 2/18/21. Further expanded to .52 on 3/23/21.
            2458187: [[0.64, 0.90]], # Flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21.
            2458187: [[0.64, 0.90]], # Flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21.
            2458189: [[0.52, 0.90]], # Weak broadband RFI + flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21.
            2458190: [[0.63, 0.90]], # Flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21.
            2458192: [[0.10, 0.90]], # X-engine died, found by Josh on inspecting notebooks 3/23/21
            2458196: [[0.64, 0.90]], # Flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21.
            2458199: [[0.10, 0.29]], # Broadband RFI early in night. Found by Josh on inspecting notebooks 3/23/21
            2458200: [[0.10, 0.26]], # Broadband RFI early in night. Found by Josh on inspecting notebooks 3/23/21
            2458201: [[0.64, 0.90]], # Flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21.
            2458205: [[0.10, 0.28]], # Broadband RFI early in night. Found by Josh on inspecting notebooks 3/23/21
            2458206: [[0.10, 0.34]], # from Vignesh's by-hand analysis H1C IDR3.1. Expanded by Josh on inspecting notebooks 3/23/21
           }

# %%
for JD in JD_flags:
    if JD_flags[JD] == [[0.10, 0.90]]:
        print(JD)
# Out:
# 2458054
# 2458055
# 2458056
# 2458061
# 2458065
# 2458066
# 2458089
# 2458140
# 2458159
# 2458161
# 2458172
# 2458173
# 2458192

# %%
# Obtained from here: https://docs.google.com/spreadsheets/d/1eDjan-p9ffmfkqrXw9V1HYDqd-FIep3KUgLNz1MU6-o/edit#gid=1450598387
with open('HERA_observing_log_IDR3.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    bad_ants, Nants, all_ants = odict(), odict(), odict()
    next(reader)
    for row in reader:
        if row['IDR3 good'] == 'TRUE': 
            bad_ants[int(row['Julian'])] = [int(ant) for ant in row['Bad Antennas'].split(',')]
            all_ants[int(row['Julian'])] = [int(ant) for ant in row['All Antennas'].split(',')]
            Nants[int(row['Julian'])] = int(row['Nants'])
            
all_bad_ants = sorted(set([ant for ants in bad_ants.values() for ant in ants]))
days = np.array(list(bad_ants.keys()))
good_days = len(bad_ants)
bad_days_by_ant = {ant: np.array([ant in bad_ants[day] or (ant in off_grid and ant in all_ants[day]) for day in days]) for ant in all_bad_ants}

# %%
day_groups = [group1, group2, group3, group4]
day_slices = [np.array([day in group for day in days]) for group in day_groups]

# %%
plt.figure()
for group in day_groups:
    plt.plot(np.array(group) - 2458000, np.ones_like(group),'.')
plt.title('Groups of Days (by color)')
plt.xlabel('JD - 2458000');

# %%
# Harmonize comissioning flags to make "analysis flags"
analysis_flags = deepcopy(bad_days_by_ant)
for ant in analysis_flags:
    for ds in day_slices:
        if np.sum(analysis_flags[ant][ds])*1.0/len(analysis_flags[ant][ds]) > .1:
            analysis_flags[ant][ds] = True
        if np.sum(analysis_flags[ant])*1.0/good_days > .6:
            analysis_flags[ant][:] = True

# %%
# Copied non-redundancy verdicts from https://github.com/HERA-Team/hera_sandbox/blob/master/jsd/IDR3_badants/IDR3_Bad_Ants.ipynb
verdicts = {54: 'Completely Flagged',
            136: 'Completely Flagged',
            69: 'Completely Flagged',
            53: 'Completely Flagged',
            117: 'Completely Flagged',
            24: 'Completely Flagged',
            67: 'Flagged Epoch 1, 2, 3',
            122: 'No New Flags',
            52: 'No New Flags',
            118: 'Flagged Epoch 3',
            137: 'No New Flags',
            12: 'No New Flags',
            84: 'No New Flags',
            41: 'Flagged on 2458141',
            100: 'No New Flags',
            87: 'No New Flags',
            1: 'No New Flags',
            102: 'No New Flags',
            23: 'No New Flags',
            11: 'Flagged on 2458190',
            68: 'No New Flags',
            141: 'No New Flags',
            86: 'No New Flags',
            13: 'No New Flags',
            143: 'No New Flags',
            85: 'No New Flags',
            138: 'No New Flags',
            142: 'No New Flags',
            82: 'No New Flags',
            123: 'No New Flags',
            38: 'No New Flags',
            25: 'No New Flags',
            120: 'No New Flags',
            51: 'No New Flags',
            71: 'No New Flags',
            55: 'No New Flags',
            139: 'No New Flags',
            88: 'No New Flags',
            124: 'No New Flags',
            121: 'No New Flags',
            37: 'No New Flags',
            14: 'No New Flags'}

# %%
for ant in verdicts:
    if ant not in bad_days_by_ant:
        bad_days_by_ant[ant] = np.zeros_like(list(bad_days_by_ant.values())[0])
    if ant not in analysis_flags:
        analysis_flags[ant] = np.zeros_like(list(analysis_flags.values())[0])

# %%
final_flags = deepcopy(analysis_flags)
for ant in verdicts:
    if 'Completely' in verdicts[ant]:
        final_flags[ant][:] = True
    if 'Epoch' in verdicts[ant]:
        for n, day_slice in zip(['1', '2', '3', '4'], day_slices):
            if n in verdicts[ant]:
                final_flags[ant][day_slice] = 1.0
    if '245' in verdicts[ant]:
        for ss in verdicts[ant].split(' '):
            try:
                indices = np.array([jd == int(ss) for jd in days])
                final_flags[ant][indices] = 1.0
            except:
                pass

# %%
ant_days = list(Nants.values())
ant_days_comm = [len([ant for ant in all_ants[day] if ant not in bad_ants[day]]) for day in days]
ant_days_analysis = [len([ant for ant in all_ants[day] if (not ant in analysis_flags or not analysis_flags[ant][n])]) for n,day in enumerate(days)]
ant_days_final = [len([ant for ant in all_ants[day] if (not ant in final_flags or not final_flags[ant][n])]) for n,day in enumerate(days)]
red_ant_days = [len([ant for ant in all_ants[day] if ant not in not_red]) for day in days]
red_ant_days_comm = [len([ant for ant in all_ants[day] if ant not in not_red and ant not in bad_ants[day]]) for day in days]
red_ant_days_analysis = [len([ant for ant in all_ants[day] if (ant not in not_red) and (not ant in analysis_flags or not analysis_flags[ant][n])]) for n,day in enumerate(days)]
red_ant_days_final = [len([ant for ant in all_ants[day] if (ant not in not_red) and (not ant in final_flags or not final_flags[ant][n])]) for n,day in enumerate(days)]

print('Total Antenna-Days:', np.sum(ant_days))
print('Total Antenna-Days After Commissioning Cuts:', np.sum(ant_days_comm))
print('Total Antenna-Days After Analysis Cuts:', np.sum(ant_days_analysis))
print('Total Antenna-Days After Redcal Cuts:', np.sum(ant_days_final))
print('Total Redundant Antenna Days:', np.sum(red_ant_days))
print('Total Redundant Antenna Days After Comissioning Cuts:', np.sum(red_ant_days_comm))
print('Total Redundant Antenna Days After Analysis Cuts:', np.sum(red_ant_days_analysis))
print('Total Redundant Antenna Days After Redcal Cuts:', np.sum(red_ant_days_final))

plt.figure(figsize=(12,4), dpi=150)
plt.subplot(121)
plt.plot(days - 2458000, ant_days,'.', label='Total')
plt.plot(days - 2458000, ant_days_comm,'.', label='After Comissioning Flags')
plt.plot(days - 2458000, ant_days_analysis,'.', label='After Analysis Team Flags')
plt.plot(days - 2458000, ant_days_final,'.', label='After Redcal Flags')
plt.xlabel('JD - 2458000')
plt.ylim([0, np.max(list(ant_days))])
plt.ylabel('Number of Antennas')
plt.legend()

plt.subplot(122)
plt.plot(days - 2458000, red_ant_days,'.', label='Total On Redundant Grid')
plt.plot(days - 2458000, red_ant_days_comm,'.', label='After Comissioning Flags')
plt.plot(days - 2458000, red_ant_days_analysis,'.', label='After Analysis Team Flags')
plt.plot(days - 2458000, red_ant_days_final,'.', label='After Redcal Flags')
plt.xlabel('JD - 2458000')
plt.ylim([0,np.max(list(ant_days))])
plt.ylabel('Number of Antennas')
plt.legend();
# Out:
# Total Antenna-Days: 5961
# Total Antenna-Days After Commissioning Cuts: 5278
# Total Antenna-Days After Analysis Cuts: 4868
# Total Antenna-Days After Redcal Cuts: 4262
# Total Redundant Antenna Days: 4818
# Total Redundant Antenna Days After Comissioning Cuts: 4417
# Total Redundant Antenna Days After Analysis Cuts: 4103
# Total Redundant Antenna Days After Redcal Cuts: 4057

# %%
print('Fraction of antenna-days flagged by commissioning:', np.sum(list(bad_days_by_ant.values())) * 1.0 / np.sum(list(Nants.values())))
print('Fraction of antenna-days flagged for analysis:', np.sum(list(analysis_flags.values())) * 1.0 / np.sum(list(Nants.values())))
print('Fraction of antenna-days flagged after redcal:', np.sum(list(final_flags.values())) * 1.0 / np.sum(list(Nants.values())))
# Out:
# Fraction of antenna-days flagged by commissioning: 0.1155846334507633
# Fraction of antenna-days flagged for analysis: 0.2120449588995135
# Fraction of antenna-days flagged after redcal: 0.32897164905217247

# %%
plt.figure()
plt.hist([np.sum(day_flags)/1.0/good_days for day_flags in bad_days_by_ant.values()], bins=100, label='Comissioning Flags')
plt.hist([np.sum(day_flags)/1.0/good_days for day_flags in analysis_flags.values()], bins=100, label='Analysis Flags')
plt.hist([np.sum(day_flags)/1.0/good_days for day_flags in final_flags.values()], bins=100, label='Redcal Flags')
plt.legend()
plt.title('Flagging Histogram')
plt.xlabel('Fraction of days flagged by antenna')
plt.ylabel('Number of antennas');

# %% [markdown]
# ## Per Antenna Flagging

# %%
for ant in sorted(list(final_flags.keys())):
    plt.figure()
    plt.plot(np.array(list(bad_ants.keys()))-2458000, bad_days_by_ant[ant], 'bo', label='Comissioning Flags', ms=8)
    plt.plot(np.array(list(bad_ants.keys()))-2458000, analysis_flags[ant], 'ro', label='Analysis Flags', ms=6)
    plt.plot(np.array(list(bad_ants.keys()))-2458000, final_flags[ant], 'ko', label='Final (Redcal) Flags', ms=4)
    
    plt.legend(loc=7)
    plt.title('Antenna ' + str(ant) + ': ' + str(int(np.sum(bad_days_by_ant[ant]) *100.0 / good_days)) + 
              '%  ==> ' + str(int(np.sum(analysis_flags[ant]) *100.0 / good_days)) + 
              '%  ==> ' + str(int(np.sum(final_flags[ant]) *100.0 / good_days)) + '%')
    plt.xlabel('JD - 2458000')
    plt.ylim([-.05, 1.05])
# Out:
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-16-c117d1415a89>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %% [markdown]
# ## Save Final Bad Antennas for Pipeline

# %%
for day in days:
    with open('bad_ants/' + str(day) + '.txt', 'w') as f:
        for ant in sorted(final_flags.keys()):
            if (ant in not_red and ant in all_ants[day]) or (day in np.array(days)[final_flags[ant]]):
                f.write(str(ant) + '\n')

# %%
JD_flags = {2458041: ([[0.50, 0.70]], "from Josh's inspecting notebooks on 2/9/21"),
            2458049: ([[0.10, 0.41]], "from Josh's inspecting notebooks on 2/9/21"),
            2458052: ([[0.50, 0.90]], "from Josh's inspecting notebooks on 2/9/21"),
            2458054: ([[0.10, 0.90]], "X-engine issues. Excluded whole day. From Josh's inspecting notebooks on 2/9/21"),
            2458055: ([[0.10, 0.90]], "X-engine issues. Excluded whole day. From Josh's inspecting notebooks on 2/9/21"),
            2458056: ([[0.10, 0.90]], "X-engine issues. Excluded whole day. From Josh's inspecting notebooks on 2/9/21"),
            2458058: ([[0.10, 0.48]], "from Vignesh's by-hand analysis H1C IDR3.1, expanded by Josh on 2/9/21"),
            2458059: ([[0.10, 0.48]], "from Vignesh's by-hand analysis H1C IDR3.1, expanded by Josh on 2/9/21"),
            2458061: ([[0.10, 0.90]], "Broadband RFI issues. Excluded whole day. From Josh's inspecting notebooks on 2/9/21"),
            2458065: ([[0.10, 0.90]], "Broadband RFI issues. Excluded whole day. From Josh's inspecting notebooks on 2/9/21"),
            2458066: ([[0.10, 0.90]], "Broadband RFI issues. Excluded whole day. From Josh's inspecting notebooks on 2/9/21"),
            2458085: ([[0.56, 0.90]], "Broadband RFI in last hour or so. From Josh's inspecting notebooks on 2/25/21"),
            2458088: ([[0.52, 0.90]], "Narrowband RFI in last few hours. From Josh's inspecting notebooks on 2/25/21"),
            2458089: ([[0.10, 0.90]], "Narrowband RFI in last few hours. From Josh's inspecting notebooks on 2/25/21. Flagged completely due to smooth_cal issues discovered 3/11/21 by Josh"),
            2458090: ([[0.50, 0.90]], "Narrowband RFI in last few hours. From Josh's inspecting notebooks on 2/26/21"),
            2458095: ([[0.10, 0.30],
                      [0.49, 0.58]], "Broadband RFI in at start of night and late in the night. From Josh's inspecting notebooks on 2/26/21"),
            2458096: ([[0.10, 0.52]], "from Vignesh's by-hand analysis H1C IDR3.1, expanded by Josh's notebook inspection on 2/26/21"),
            2458104: ([[0.10, 0.47]], "from Vignesh's by-hand analysis H1C IDR3.1, expanded by Josh's notebook inspection on 2/26/21"),
            2458105: ([[0.10, 0.43]], "Broadband RFI for first half of the night. From Josh's inspecting notebooks on 2/26/21"),
            2458109: ([[0.20, 0.46]], "from Vignesh's by-hand analysis H1C IDR3.1"),
            2458110: ([[0.47, 0.90]], "Narrowband RFI in last few hours. From Josh's inspecting notebooks on 2/26/21"),
            2458114: ([[0.10, 0.32]], "flagged due to a broken X-engine "),
            2458135: ([[0.10, 0.43]], "flagged due to excess broadband RFI. From Josh's inspecting notebooks on 3/9/21"),
            2458136: ([[0.20, 0.43]], "from Vignesh's by-hand analysis H1C IDR3.1, expanded from Josh's inspecting notebooks on 3/9/21"),
            2458139: ([[0.10, 0.34]], "flagged due to excess broadband RFI. From Josh's inspecting notebooks on 3/9/21"),
            2458140: ([[0.10, 0.90]], "added by Josh on 12/29/20, expanded to full day flag from Josh's inspecting notebooks on 3/9/21"),
            2458141: ([[0.10, 0.52]], "from Vignesh's by-hand analysis H1C IDR3.1. Expanded from Josh's inspecting notebooks on 3/9/21"),
            2458144: ([[0.10, 0.31]], "flagged due to excess broadband RFI. From Josh's inspecting notebooks on 3/9/21"),
            2458145: ([[0.10, 0.38]], "flagged due to excess broadband RFI. From Josh's inspecting notebooks on 3/9/21"),
            2458148: ([[0.10, 0.37]], "from Vignesh's by-hand analysis H1C IDR3.1. Expanded from Josh's inspecting notebooks on 3/9/21"),
            2458157: ([[0.46, 0.90]], "Omnical issues, possibly non-convergence. From Josh's inspecting notebooks on 3/9/21"),
            2458159: ([[0.10, 0.90]], "from Vignesh's by-hand analysis H1C IDR3.1, expanded to full day flag from Josh's inspecting notebooks on 3/9/21"),
            2458161: ([[0.10, 0.90]], "from Vignesh's by-hand analysis H1C IDR3.1. Excluded by Josh on inpsectiing notebooks 2/18/21"),
            2458172: ([[0.10, 0.90]], "from Vignesh's by-hand analysis H1C IDR3.1. Excluded by Josh on inspecting notebooks 2/18/21"),
            2458173: ([[0.10, 0.90]], "from Vignesh's by-hand analysis H1C IDR3.1. Excluded by Josh on inspecting notebooks 2/18/21"),
            2458185: ([[0.10, 0.52]], "from Vignesh's by-hand analysis H1C IDR3.1. Expanded by Josh on inspecting notebooks 2/18/21. Further expanded to .52 on 3/23/21."),
            2458187: ([[0.64, 0.90]], "Flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21."),
            2458187: ([[0.64, 0.90]], "Flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21."),
            2458189: ([[0.52, 0.90]], "Weak broadband RFI + flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21."),
            2458190: ([[0.63, 0.90]], "Flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21."),
            2458192: ([[0.10, 0.90]], "X-engine died, found by Josh on inspecting notebooks 3/23/21"),
            2458196: ([[0.64, 0.90]], "Flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21."),
            2458199: ([[0.10, 0.29]], "Broadband RFI early in night. Found by Josh on inspecting notebooks 3/23/21"),
            2458200: ([[0.10, 0.26]], "Broadband RFI early in night. Found by Josh on inspecting notebooks 3/23/21"),
            2458201: ([[0.64, 0.90]], "Flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21."),
            2458205: ([[0.10, 0.28]], "Broadband RFI early in night. Found by Josh on inspecting notebooks 3/23/21"),
            2458206: ([[0.10, 0.34]], "from Vignesh's by-hand analysis H1C IDR3.1. Expanded by Josh on inspecting notebooks 3/23/21"),
           }

# %%
for jd in JD_flags:
    for rng in JD_flags[jd][0]:
        if rng[0] == .1 and rng[1] == .9:
            continue
        if rng[0] == .1:
            rng[0] = 0
        if rng[1] == .9:
            rng[1] = .99
        print(f'{jd+rng[0]:.2f} -- {jd+rng[1]:.2f} & {JD_flags[jd][1]} \\\ \hline')
# Out:
# 2458041.50 -- 2458041.70 & from Josh's inspecting notebooks on 2/9/21 \\ \hline
# 2458049.00 -- 2458049.41 & from Josh's inspecting notebooks on 2/9/21 \\ \hline
# 2458052.50 -- 2458052.99 & from Josh's inspecting notebooks on 2/9/21 \\ \hline
# 2458058.00 -- 2458058.48 & from Vignesh's by-hand analysis H1C IDR3.1, expanded by Josh on 2/9/21 \\ \hline
# 2458059.00 -- 2458059.48 & from Vignesh's by-hand analysis H1C IDR3.1, expanded by Josh on 2/9/21 \\ \hline
# 2458085.56 -- 2458085.99 & Broadband RFI in last hour or so. From Josh's inspecting notebooks on 2/25/21 \\ \hline
# 2458088.52 -- 2458088.99 & Narrowband RFI in last few hours. From Josh's inspecting notebooks on 2/25/21 \\ \hline
# 2458090.50 -- 2458090.99 & Narrowband RFI in last few hours. From Josh's inspecting notebooks on 2/26/21 \\ \hline
# 2458095.00 -- 2458095.30 & Broadband RFI in at start of night and late in the night. From Josh's inspecting notebooks on 2/26/21 \\ \hline
# 2458095.49 -- 2458095.58 & Broadband RFI in at start of night and late in the night. From Josh's inspecting notebooks on 2/26/21 \\ \hline
# 2458096.00 -- 2458096.52 & from Vignesh's by-hand analysis H1C IDR3.1, expanded by Josh's notebook inspection on 2/26/21 \\ \hline
# 2458104.00 -- 2458104.47 & from Vignesh's by-hand analysis H1C IDR3.1, expanded by Josh's notebook inspection on 2/26/21 \\ \hline
# 2458105.00 -- 2458105.43 & Broadband RFI for first half of the night. From Josh's inspecting notebooks on 2/26/21 \\ \hline
# 2458109.20 -- 2458109.46 & from Vignesh's by-hand analysis H1C IDR3.1 \\ \hline
# 2458110.47 -- 2458110.99 & Narrowband RFI in last few hours. From Josh's inspecting notebooks on 2/26/21 \\ \hline
# 2458114.00 -- 2458114.32 & flagged due to a broken X-engine  \\ \hline
# 2458135.00 -- 2458135.43 & flagged due to excess broadband RFI. From Josh's inspecting notebooks on 3/9/21 \\ \hline
# 2458136.20 -- 2458136.43 & from Vignesh's by-hand analysis H1C IDR3.1, expanded from Josh's inspecting notebooks on 3/9/21 \\ \hline
# 2458139.00 -- 2458139.34 & flagged due to excess broadband RFI. From Josh's inspecting notebooks on 3/9/21 \\ \hline
# 2458141.00 -- 2458141.52 & from Vignesh's by-hand analysis H1C IDR3.1. Expanded from Josh's inspecting notebooks on 3/9/21 \\ \hline
# 2458144.00 -- 2458144.31 & flagged due to excess broadband RFI. From Josh's inspecting notebooks on 3/9/21 \\ \hline
# 2458145.00 -- 2458145.38 & flagged due to excess broadband RFI. From Josh's inspecting notebooks on 3/9/21 \\ \hline
# 2458148.00 -- 2458148.37 & from Vignesh's by-hand analysis H1C IDR3.1. Expanded from Josh's inspecting notebooks on 3/9/21 \\ \hline
# 2458157.46 -- 2458157.99 & Omnical issues, possibly non-convergence. From Josh's inspecting notebooks on 3/9/21 \\ \hline
# 2458185.00 -- 2458185.52 & from Vignesh's by-hand analysis H1C IDR3.1. Expanded by Josh on inspecting notebooks 2/18/21. Further expanded to .52 on 3/23/21. \\ \hline
# 2458187.64 -- 2458187.99 & Flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21. \\ \hline
# 2458189.52 -- 2458189.99 & Weak broadband RFI + flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21. \\ \hline
# 2458190.63 -- 2458190.99 & Flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21. \\ \hline
# 2458196.64 -- 2458196.99 & Flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21. \\ \hline
# 2458199.00 -- 2458199.29 & Broadband RFI early in night. Found by Josh on inspecting notebooks 3/23/21 \\ \hline
# 2458200.00 -- 2458200.26 & Broadband RFI early in night. Found by Josh on inspecting notebooks 3/23/21 \\ \hline
# 2458201.64 -- 2458201.99 & Flag some galaxy to prevent smooth_cal issues found by Josh on inspecting notebooks on 3/23/21. \\ \hline
# 2458205.00 -- 2458205.28 & Broadband RFI early in night. Found by Josh on inspecting notebooks 3/23/21 \\ \hline
# 2458206.00 -- 2458206.34 & from Vignesh's by-hand analysis H1C IDR3.1. Expanded by Josh on inspecting notebooks 3/23/21 \\ \hline
